# %%
import numpy as np
from numpy.core.umath_tests import inner1d
import pandas as pd
from sklearn.linear_model import LogisticRegressionCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
# %matplotlib inline

# %%
pd.get_option("display.max_columns")
pd.set_option('display.max_columns', 50)

# %%
train_df = pd.read_csv("./data/train.csv")
test_df = pd.read_csv("./data/test.csv")

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_PassengerId = train_df['PassengerId']
test_PassengerId = test_df['PassengerId']

# %%
test_df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# どれを残すか、どのobject(文字列)をカテゴリに変換するか考える

# %% [markdown]
# PassengerIdは保管したので学習しないようにdrop
# Nameはいらないからdrop
# Ticket、Cabin、Embarkedは詳細を見てから

# %%
train_df.drop(['PassengerId','Name'], axis=1, inplace=True)
test_df.drop(['PassengerId','Name'], axis=1, inplace=True)

# %%
train_df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# AgeとCabinとEmbarkedに欠損値がある。
# Cabinは多すぎるのでdropさせることに決定

# %%
train_df.drop(['Cabin'], axis=1, inplace=True)
test_df.drop(['Cabin'], axis=1, inplace=True)

# %%
train_df['Ticket'].unique
# Out:
# <bound method Series.unique of 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
# 5                330877
# 6                 17463
# 7                349909
# 8                347742
# 9                237736
# 10              PP 9549
# 11               113783
# 12            A/5. 2151
# 13               347082
# 14               350406
# 15               248706
# 16               382652
# 17               244373
# 18               345763
# 19                 2649
# 20               239865
# 21               248698
# 22               330923
# 23               113788
# 24               349909
# 25               347077
# 26                 2631
# 27                19950
# 28               330959
# 29               349216
#              ...
# 861               28134
# 862               17466
# 863            CA. 2343
# 864              233866
# 865              236852
# 866       SC/PARIS 2149
# 867            PC 17590
# 868              345777
# 869              347742
# 870              349248
# 871               11751
# 872                 695
# 873              345765
# 874           P/PP 3381
# 875                2667
# 876                7534
# 877              349212
# 878              349217
# 879               11767
# 880              230433
# 881              349257
# 882                7552
# 883    C.A./SOTON 34068
# 884     SOTON/OQ 392076
# 885              382652
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object>

# %% [markdown]
# Ticketはユニークなのでdropする

# %%
train_df.drop(['Ticket'], axis=1, inplace=True)
test_df.drop(['Ticket'], axis=1, inplace=True)

# %% [markdown]
# Sexをカテゴリ化してダミー変数化する

# %%
train_df['Sex'] = pd.Categorical(train_df['Sex'])
test_df['Sex'] = pd.Categorical(test_df['Sex'])

# %%
train_df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
dummy_vars_train = pd.get_dummies(train_df['Sex'], drop_first=False)
dummy_vars_test = pd.get_dummies(test_df['Sex'], drop_first=False)

# %%
train_df = pd.concat([train_df, dummy_vars_train], axis=1)
test_df = pd.concat([test_df, dummy_vars_test], axis=1)

# %% [markdown]
# Sexをダミー変数化できたので、Sexをdrop

# %%
train_df.drop(['Sex'], axis=1, inplace=True)
test_df.drop(['Sex'], axis=1, inplace=True)

# %%
train_df
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare Embarked  female  male
# 0           0       3  22.0      1      0    7.2500        S       0     1
# 1           1       1  38.0      1      0   71.2833        C       1     0
# 2           1       3  26.0      0      0    7.9250        S       1     0
# 3           1       1  35.0      1      0   53.1000        S       1     0
# 4           0       3  35.0      0      0    8.0500        S       0     1
# 5           0       3   NaN      0      0    8.4583        Q       0     1
# 6           0       1  54.0      0      0   51.8625        S       0     1
# 7           0       3   2.0      3      1   21.0750        S       0     1
# 8           1       3  27.0      0      2   11.1333        S       1     0
# 9           1       2  14.0      1      0   30.0708        C       1     0
# 10          1       3   4.0      1      1   16.7000        S       1     0
# 11          1       1  58.0      0      0   26.5500        S       1     0
# 12          0       3  20.0      0      0    8.0500        S       0     1
# 13          0       3  39.0      1      5   31.2750        S       0     1
# 14          0       3  14.0      0      0    7.8542        S       1     0
# 15          1       2  55.0      0      0   16.0000        S       1     0
# 16          0       3   2.0      4      1   29.1250        Q       0     1
# 17          1       2   NaN      0      0   13.0000        S       0     1
# 18          0       3  31.0      1      0   18.0000        S       1     0
# 19          1       3   NaN      0      0    7.2250        C       1     0
# 20          0       2  35.0      0      0   26.0000        S       0     1
# 21          1       2  34.0      0      0   13.0000        S       0     1
# 22          1       3  15.0      0      0    8.0292        Q       1     0
# 23          1       1  28.0      0      0   35.5000        S       0     1
# 24          0       3   8.0      3      1   21.0750        S       1     0
# 25          1       3  38.0      1      5   31.3875        S       1     0
# 26          0       3   NaN      0      0    7.2250        C       0     1
# 27          0       1  19.0      3      2  263.0000        S       0     1
# 28          1       3   NaN      0      0    7.8792        Q       1     0
# 29          0       3   NaN      0      0    7.8958        S       0     1
# ..        ...     ...   ...    ...    ...       ...      ...     ...   ...
# 861         0       2  21.0      1      0   11.5000        S       0     1
# 862         1       1  48.0      0      0   25.9292        S       1     0
# 863         0       3   NaN      8      2   69.5500        S       1     0
# 864         0       2  24.0      0      0   13.0000        S       0     1
# 865         1       2  42.0      0      0   13.0000        S       1     0
# 866         1       2  27.0      1      0   13.8583        C       1     0
# 867         0       1  31.0      0      0   50.4958        S       0     1
# 868         0       3   NaN      0      0    9.5000        S       0     1
# 869         1       3   4.0      1      1   11.1333        S       0     1
# 870         0       3  26.0      0      0    7.8958        S       0     1
# 871         1       1  47.0      1      1   52.5542        S       1     0
# 872         0       1  33.0      0      0    5.0000        S       0     1
# 873         0       3  47.0      0      0    9.0000        S       0     1
# 874         1       2  28.0      1      0   24.0000        C       1     0
# 875         1       3  15.0      0      0    7.2250        C       1     0
# 876         0       3  20.0      0      0    9.8458        S       0     1
# 877         0       3  19.0      0      0    7.8958        S       0     1
# 878         0       3   NaN      0      0    7.8958        S       0     1
# 879         1       1  56.0      0      1   83.1583        C       1     0
# 880         1       2  25.0      0      1   26.0000        S       1     0
# 881         0       3  33.0      0      0    7.8958        S       0     1
# 882         0       3  22.0      0      0   10.5167        S       1     0
# 883         0       2  28.0      0      0   10.5000        S       0     1
# 884         0       3  25.0      0      0    7.0500        S       0     1
# 885         0       3  39.0      0      5   29.1250        Q       1     0
# 886         0       2  27.0      0      0   13.0000        S       0     1
# 887         1       1  19.0      0      0   30.0000        S       1     0
# 888         0       3   NaN      1      2   23.4500        S       1     0
# 889         1       1  26.0      0      0   30.0000        C       0     1
# 890         0       3  32.0      0      0    7.7500        Q       0     1
#
# [891 rows x 9 columns]

# %% [markdown]
# Pclassが数値データになっているので、カテゴリデータ化してダミー変数化
# 1 = 1st
# 2 = 2nd
# 3 = 3rd

# %%
train_df['Pclass'].replace({1:"1st", 2:"2nd", 3:"3rd"}, inplace=True)
test_df['Pclass'].replace({1:"1st", 2:"2nd", 3:"3rd"}, inplace=True)

# %%
dummy_vars_train = pd.get_dummies(train_df['Pclass'], drop_first=False)
dummy_vars_test = pd.get_dummies(test_df['Pclass'], drop_first=False)

# %%
train_df = pd.concat([train_df, dummy_vars_train], axis=1)
test_df = pd.concat([test_df, dummy_vars_test], axis=1)

# %%
train_df.drop(['Pclass'], axis=1, inplace=True)
test_df.drop(['Pclass'], axis=1, inplace=True)

# %%
train_df.dtypes
# Out:
# Survived      int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# female        uint8
# male          uint8
# 1st           uint8
# 2nd           uint8
# 3rd           uint8
# dtype: object

# %%
train_df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
# 10     S
# 11     S
# 12     S
# 13     S
# 14     S
# 15     S
# 16     Q
# 17     S
# 18     S
# 19     C
# 20     S
# 21     S
# 22     Q
# 23     S
# 24     S
# 25     S
# 26     C
# 27     S
# 28     Q
# 29     S
#       ..
# 861    S
# 862    S
# 863    S
# 864    S
# 865    S
# 866    C
# 867    S
# 868    S
# 869    S
# 870    S
# 871    S
# 872    S
# 873    S
# 874    C
# 875    C
# 876    S
# 877    S
# 878    S
# 879    C
# 880    S
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
train_df['Embarked'].replace({'C':"Cherbourg", 'Q':"Queenstown", 'S':"Southampton"}, inplace=True)
test_df['Embarked'].replace({'C':"Cherbourg", 'Q':"Queenstown", 'S':"Southampton"}, inplace=True)

# %%
dummy_vars_train = pd.get_dummies(train_df['Embarked'], drop_first=False)
dummy_vars_test = pd.get_dummies(test_df['Embarked'], drop_first=False)

# %%
train_df = pd.concat([train_df, dummy_vars_train], axis=1)
test_df = pd.concat([test_df, dummy_vars_test], axis=1)

# %%
train_df.drop(['Embarked'], axis=1, inplace=True)
test_df.drop(['Embarked'], axis=1, inplace=True)

# %%
train_df.isnull().sum()
# Out:
# Survived         0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# female           0
# male             0
# 1st              0
# 2nd              0
# 3rd              0
# Cherbourg        0
# Queenstown       0
# Southampton      0
# dtype: int64

# %%
train_df.isnull().sum()
# Out:
# Survived         0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# female           0
# male             0
# 1st              0
# 2nd              0
# 3rd              0
# Cherbourg        0
# Queenstown       0
# Southampton      0
# dtype: int64

# %%
pd.concat([train_df['Age'],test_df['Age']]).median()
# Out:
# 28.0

# %% [markdown]
# Nanは中央値で埋める

# %%
train_df.fillna(pd.concat([train_df['Age'],test_df['Age']]).median(), inplace=True)
test_df.fillna(pd.concat([train_df['Age'],test_df['Age']]).median(), inplace=True)

# %%
test_df.fillna(pd.concat([train_df['Fare'],test_df['Fare']]).median(), inplace=True)

# %%
train_df.isnull().sum()
# Out:
# Survived       0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# female         0
# male           0
# 1st            0
# 2nd            0
# 3rd            0
# Cherbourg      0
# Queenstown     0
# Southampton    0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# female         0
# male           0
# 1st            0
# 2nd            0
# 3rd            0
# Cherbourg      0
# Queenstown     0
# Southampton    0
# dtype: int64

# %% [raw]
# test_df.dtypes

# %% [markdown]
# これで欠損値もなく、数値データになったので、学習に食わせてみる。
# RandomForestと線形回帰を試してみよう

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df.drop(['Survived'],axis=1), train_df['Survived'], random_state=0)

# %% [markdown]
# #### ロジスティック回帰

# %%
LR = LogisticRegression(C=0.01)
LR = LR.fit(X_train, y_train)

# %%
print("Training set score: {:.3f}".format(LR.score(X_train, y_train)))
print("test set score: {:.3f}".format(LR.score(X_test, y_test)))
# Out:
# Training set score: 0.771
# test set score: 0.794

# %% [markdown]
# K分割交差法

# %%
logreg = LogisticRegression()
scores = cross_val_score(logreg, X_train, y_train)

# %%
scores = cross_val_score(logreg, train_df.drop(['Survived'],axis=1), train_df['Survived'], cv=10)
LRscores = cross_val_score(LR, train_df.drop(['Survived'],axis=1), train_df['Survived'], cv=10)

# %%
scores.mean()
# Out:
# 0.8003209056860742

# %% [markdown]
# #### RandomForest

# %%
forest = RandomForestClassifier(n_estimators=8, random_state=2)
forest.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(forest.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(forest.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.958
# Accuracy on test set: 0.816

# %%
RFscores = cross_val_score(forest, train_df.drop(['Survived'],axis=1), train_df['Survived'], cv=10)

# %%
RFscores.mean()
# Out:
# 0.8193723754397911

# %% [markdown]
# とりあえずランダムフォレストで予測をする

# %%
prediction = forest.predict(test_df)

# %%
prediction_df = pd.DataFrame(prediction)

# %%
test_PassengerId
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
# 5       897
# 6       898
# 7       899
# 8       900
# 9       901
# 10      902
# 11      903
# 12      904
# 13      905
# 14      906
# 15      907
# 16      908
# 17      909
# 18      910
# 19      911
# 20      912
# 21      913
# 22      914
# 23      915
# 24      916
# 25      917
# 26      918
# 27      919
# 28      920
# 29      921
#        ...
# 388    1280
# 389    1281
# 390    1282
# 391    1283
# 392    1284
# 393    1285
# 394    1286
# 395    1287
# 396    1288
# 397    1289
# 398    1290
# 399    1291
# 400    1292
# 401    1293
# 402    1294
# 403    1295
# 404    1296
# 405    1297
# 406    1298
# 407    1299
# 408    1300
# 409    1301
# 410    1302
# 411    1303
# 412    1304
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
submit_df = pd.concat([test_PassengerId,prediction_df],axis=1)

# %%
submit_df.rename(columns={0:'Survived'}, inplace=True)

# %%
submit_df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         1
# 18           910         0
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         1
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         0
# 391         1283         1
# 392         1284         1
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         1
# 405         1297         1
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         0
# 410         1302         1
# 411         1303         1
# 412         1304         0
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
submit_df.to_csv("./result/submission.csv", index=False)
